# %%
import pandas as pd

# %%
d1 = pd.read_csv('../Data/Power.csv')

# %%
d1.shape
# Out:
# (152, 22)

# %%
d1
# Out:
#          b   leafValue( getData(":pwr" ?result "dc") "a" 2.88e-06 ) (W)  \
# 0     620.0                                           0.000325
# 1     625.5                                           0.000325
# 2     631.0                                           0.000325
# 3     636.5                                           0.000325
# 4     642.0                                           0.000324
# ..      ...                                                ...
# 147  1430.0                                           0.000290
# 148  1430.0                                           0.000290
# 149  1440.0                                           0.000289
# 150  1450.0                                           0.000289
# 151  1450.0                                           0.000289
#
#      leafValue( getData(":pwr" ?result "dc") "a" 3.0675e-06 ) (W)  \
# 0                                             0.000344
# 1                                             0.000344
# ...

# %%
d2 = pd.read_csv('../Data/BW-3000.csv')

# %%
d2.shape
# Out:
# (21, 303)

# %%
d2
# Out:
#        width  Unnamed: 1           620  Unnamed: 3         625.5  Unnamed: 5  \
# 0   0.000003       3.775  8.280000e+10       3.839  8.200000e+10       3.902
# 1   0.000003       4.230  7.700000e+10       4.293  7.620000e+10       4.356
# 2   0.000003       4.652  7.200000e+10       4.715  7.130000e+10       4.776
# 3   0.000003       5.046  6.770000e+10       5.107  6.700000e+10       5.168
# 4   0.000004       5.414  6.390000e+10       5.474  6.330000e+10       5.534
# 5   0.000004       5.758  6.050000e+10       5.818  6.000000e+10       5.877
# 6   0.000004       6.081  5.750000e+10       6.140  5.700000e+10       6.198
# 7   0.000004       6.385  5.490000e+10       6.443  5.440000e+10       6.500
# 8   0.000004       6.671  5.240000e+10       6.728  5.200000e+10       6.784
# 9   0.000005       6.940  5.020000e+10       6.996  4.980000e+10       7.052
# 10  0.000005       7.195  4.820000e+10       7.250  4.780000e+10       7.304
# ...

# %%
gain 3 bandiwth 5 width 10 resistor 20 power 40

# %%
3,5,10,20,40

# %%
#
